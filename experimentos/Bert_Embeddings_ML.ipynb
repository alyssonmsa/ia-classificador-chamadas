# %% [markdown]
# ## QuantumFinance - Parte Extra: BERT como Extrator de Features + ML Clássico
#
# ### Objetivo
#
# Este notebook explora uma abordagem alternativa ao fine-tuning do BERT: utilizamos embeddings gerados por um modelo transformer pré-treinado para representar os textos e treinamos modelos de classificação tradicionais (como Regressão Logística e Random Forest) sobre esses embeddings.
#
# ---

# %%
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sentence_transformers import SentenceTransformer
from sklearn import preprocessing

# %%
DEV_MODE = True
TEST_SIZE = 0.25
RANDOM_STATE = 42

df = pd.read_csv('tickets_reclamacoes_classificados.csv', sep=';')
if DEV_MODE:
    df = df.sample(frac=0.1, random_state=RANDOM_STATE).reset_index(drop=True)

# %%
#normalizacao 

import re
import string

def remove_punctuation(text):
    table = str.maketrans('', '', string.punctuation)
    return text.translate(table)

def normalize_text(text):
    institution_names = ['chase', 'bank', 'jp', 'gm', 'financial', 'jpmcb']
    text = text.lower()
    text = re.sub(r'\d+|/', '', text)
    text = re.sub(r'\bx\b|\w*xx+\w*', '', text)
    text = remove_punctuation(text)
    text = re.sub(r'\s+', ' ', text).strip()
    for inst in institution_names:
        text = re.sub(r'\b' + re.escape(inst) + r'\b', '[INST]', text)
    return text

df['texto_limpo'] = df['descricao_reclamacao'].apply(normalize_text)
df
# Out:
#       id_reclamacao              data_abertura  \
# 0           2505290  2017-06-08T12:00:00-05:00
# 1           3625355  2020-04-27T12:00:00-05:00
# 2           1405636  2015-06-04T12:00:00-05:00
# 3           2915672  2018-05-23T12:00:00-05:00
# 4           1733697  2016-01-08T12:00:00-05:00
# ...             ...                        ...
# 2102        1592842  2015-10-05T12:00:00-05:00
# 2103        4182434  2021-03-04T12:00:00-05:00
# 2104        1542982  2015-08-28T12:00:00-05:00
# 2105        2682483  2017-09-23T12:00:00-05:00
# 2106        2496015  2017-05-28T12:00:00-05:00
#
#                                 categoria  \
# 0              Serviços de conta bancária
# 1            Roubo / Relatório de disputa
# 2                 Hipotecas / Empréstimos
# 3            Roubo / Relatório de disputa
# 4            Roubo / Relatório de disputa
# ...                                   ...
# 2102           Serviços de conta bancária
# 2103  Cartão de crédito / Cartão pré-pago
# 2104                               Outros
# 2105           Serviços de conta bancária
# 2106              Hipotecas / Empréstimos
#
#                                    descricao_reclamacao  \
# 0     Oxxxx xxxx pagou o JP Morgan Chase {$ 1200.00}...
# 1     Perdi meu cartão de crédito (uma reserva de sa...
# 2     Em 2005, fui para xxxx xxxx xxxx. Eles me dire...
# 3     Eu me inscrevi e recebi um cartão de crédito p...
# 4     Com o Chase A {$ 620,00} Charge (xxxx 2015) fo...
# ...                                                 ...
# 2102  JP Morgan Chase Bank, xxxx xxxx xxxx, xxxx xxx...
# 2103  Eu arquivei uma disputa em relação a itens inc...
# 2104  Eu tenho uma propriedade secundária na qual co...
# 2105  Recebi uma grande quantia de dinheiro como pre...
# 2106  Chase Sho WS um empréstimo de patrimônio ainda...
#
#                                             texto_limpo
# 0     pagou o [INST] morgan [INST] para pagamento de...
# 1     perdi meu cartão de crédito uma reserva de saf...
# 2     em fui para eles me direcionaram ao banco de u...
# 3     eu me inscrevi e recebi um cartão de crédito p...
# 4     com o [INST] a charge foi originalmente contes...
# ...                                                 ...
# 2102  [INST] morgan [INST] [INST] fl eu tenho uma co...
# 2103  eu arquivei uma disputa em relação a itens inc...
# 2104  eu tenho uma propriedade secundária na qual co...
# 2105  recebi uma grande quantia de dinheiro como pre...
# 2106  [INST] sho ws um empréstimo de patrimônio aind...
#
# [2107 rows x 5 columns]

# %%
#encoder 

label_encoder = preprocessing.LabelEncoder()
df['label'] = label_encoder.fit_transform(df['categoria'])

# %%
## Split dos Dados (Treino/Teste)

X_train, X_test, y_train, y_test = train_test_split(
    df['texto_limpo'], df['label'], test_size=TEST_SIZE,
    random_state=RANDOM_STATE, stratify=df['label']
)

# %%
## Geração dos Embeddings com SentenceTransformer


print("Carregando modelo de embeddings...")
model = SentenceTransformer('neuralmind/bert-base-portuguese-cased', device='cuda' if torch.cuda.is_available() else 'cpu')

print("Gerando embeddings de treino e teste...")
X_train_embeddings = model.encode(X_train.tolist(), show_progress_bar=True)
X_test_embeddings = model.encode(X_test.tolist(), show_progress_bar=True)
# Out:
# Carregando modelo de embeddings...
# No sentence-transformers model found with name neuralmind/bert-base-portuguese-cased. Creating a new one with mean pooling.
# Gerando embeddings de treino e teste...
# Batches:   0%|          | 0/50 [00:00<?, ?it/s]
# Batches:   0%|          | 0/17 [00:00<?, ?it/s]

# %%
## Treinamento e Avaliação com Modelos Clássicos

modelos = {
    'LogisticRegression': LogisticRegression(max_iter=1000),
    'RandomForest': RandomForestClassifier(),
    'LinearSVC': LinearSVC(),
    'GradientBoosting': GradientBoostingClassifier(),
    'GaussianNB': GaussianNB()
}

print("\nResultados:")
for nome, modelo in modelos.items():
    try:
        modelo.fit(X_train_embeddings, y_train)
        y_pred = modelo.predict(X_test_embeddings)
        f1 = f1_score(y_test, y_pred, average='weighted')
        print(f'{nome:<20} → F1 Score: {f1:.2%}')
        print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
    except Exception as e:
        print(f'{nome:<20} → Erro: {e}')
# Out:
# Resultados:
# LogisticRegression   → F1 Score: 77.20%
#                                      precision    recall  f1-score   support
#
# Cartão de crédito / Cartão pré-pago       0.77      0.76      0.76       126
#             Hipotecas / Empréstimos       0.81      0.78      0.80        88
#                              Outros       0.82      0.62      0.71        53
#        Roubo / Relatório de disputa       0.68      0.74      0.71       125
#          Serviços de conta bancária       0.83      0.86      0.84       135
#
#                            accuracy                           0.77       527
#                           macro avg       0.78      0.75      0.77       527
#                        weighted avg       0.78      0.77      0.77       527
#
# RandomForest         → F1 Score: 66.85%
#                                      precision    recall  f1-score   support
#
# Cartão de crédito / Cartão pré-pago       0.67      0.73      0.70       126
#             Hipotecas / Empréstimos       0.75      0.69      0.72        88
#                              Outros       1.00      0.25      0.39        53
#        Roubo / Relatório de disputa       0.59      0.69      0.63       125
#          Serviços de conta bancária       0.71      0.79      0.74       135
#
#                            accuracy                           0.68       527
#                           macro avg       0.74      0.63      0.64       527
#                        weighted avg       0.71      0.68      0.67       527
#
# LinearSVC            → F1 Score: 76.31%
#                                      precision    recall  f1-score   support
#
# Cartão de crédito / Cartão pré-pago       0.78      0.77      0.77       126
#             Hipotecas / Empréstimos       0.74      0.78      0.76        88
#                              Outros       0.83      0.55      0.66        53
#        Roubo / Relatório de disputa       0.71      0.77      0.74       125
#          Serviços de conta bancária       0.81      0.83      0.82       135
#
#                            accuracy                           0.76       527
#                           macro avg       0.77      0.74      0.75       527
#                        weighted avg       0.77      0.76      0.76       527
#
# GradientBoosting     → F1 Score: 72.60%
#                                      precision    recall  f1-score   support
#
# Cartão de crédito / Cartão pré-pago       0.73      0.71      0.72       126
#             Hipotecas / Empréstimos       0.82      0.76      0.79        88
#                              Outros       0.83      0.47      0.60        53
#        Roubo / Relatório de disputa       0.63      0.71      0.67       125
#          Serviços de conta bancária       0.75      0.84      0.79       135
#
#                            accuracy                           0.73       527
#                           macro avg       0.75      0.70      0.71       527
#                        weighted avg       0.74      0.73      0.73       527
#
# GaussianNB           → F1 Score: 62.43%
#                                      precision    recall  f1-score   support
#
# Cartão de crédito / Cartão pré-pago       0.56      0.53      0.54       126
#             Hipotecas / Empréstimos       0.76      0.75      0.75        88
#                              Outros       0.51      0.51      0.51        53
#        Roubo / Relatório de disputa       0.53      0.64      0.58       125
#          Serviços de conta bancária       0.75      0.65      0.70       135
#
#                            accuracy                           0.62       527
#                           macro avg       0.62      0.62      0.62       527
#                        weighted avg       0.63      0.62      0.62       527
